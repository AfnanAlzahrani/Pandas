# %% [markdown]
# ## Import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# ## Read csv format

# %%
df0 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data",
names = ["Sex"," Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight","Shell weight","Rings"] )

# %% [markdown]
# ## Dataframe

# %%
df0.head()
# Out:
#   Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 0   M    0.455      0.365   0.095        0.5140          0.2245
# 1   M    0.350      0.265   0.090        0.2255          0.0995
# 2   F    0.530      0.420   0.135        0.6770          0.2565
# 3   M    0.440      0.365   0.125        0.5160          0.2155
# 4   I    0.330      0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# ## This displays the dimensions of our dataset and allows us to see the column and row count

# %%
shape = df0.shape

# %%
print(shape)
# Out:
# (4177, 9)

# %% [markdown]
# ## Viewing the ‘tail end’ of the dataset.

# %%
df0.tail()
# Out:
#      Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 4172   F    0.565      0.450   0.165        0.8870          0.3700
# 4173   M    0.590      0.440   0.135        0.9660          0.4390
# 4174   M    0.600      0.475   0.205        1.1760          0.5255
# 4175   F    0.625      0.485   0.150        1.0945          0.5310
# 4176   M    0.710      0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# ## describe all numerical features

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].describe() 
#df.describe() This displays a set of descriptive statistics for our dataset
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# ## Describe all categorical features

# %%
df0[['Sex']].describe()
# Out:
#          Sex
# count   4177
# unique     3
# top        M
# freq    1528

# %% [markdown]
# # Mean for all numerical columns

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].mean()
# We use the mean() function if we wish to take the mean or average of a particular column within our dataset.
# Out:
#  Length           0.523992
#  Diameter         0.407881
# Height            0.139516
# Whole weight      0.828742
# Shucked weight    0.359367
# Viscera weight    0.180594
# Shell weight      0.238831
# Rings             9.933684
# dtype: float64

# %% [markdown]
# ## Median for all numerical columns

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].median()
#The median() method returns a Series with the median value of each column
# Out:
#  Length           0.5450
#  Diameter         0.4250
# Height            0.1400
# Whole weight      0.7995
# Shucked weight    0.3360
# Viscera weight    0.1710
# Shell weight      0.2340
# Rings             9.0000
# dtype: float64

# %% [markdown]
# ## Mode for all numerical columns

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].mode()
#The mode() method returns the mode value of each column.
# Out:
#     Length   Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0    0.550       0.45    0.15        0.2225           0.175          0.1715
# 1    0.625        NaN     NaN           NaN             NaN             NaN
#
#    Shell weight  Rings
# 0         0.275    9.0
# 1           NaN    NaN

# %% [markdown]
# ## Standard deviation for all numerical columns

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].std()
# The Pandas std() is defined as a function for calculating the standard deviation
# Out:
#  Length           0.120093
#  Diameter         0.099240
# Height            0.041827
# Whole weight      0.490389
# Shucked weight    0.221963
# Viscera weight    0.109614
# Shell weight      0.139203
# Rings             3.224169
# dtype: float64

# %% [markdown]
# ## Sum for all numerical columns

# %%
df0[[" Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].sum()
#We can use the sum() function to find the sum of all the values over the index axis
# Out:
#  Length            2188.7150
#  Diameter          1703.7200
# Height              582.7600
# Whole weight       3461.6560
# Shucked weight     1501.0780
# Viscera weight      754.3395
# Shell weight        997.5965
# Rings             41493.0000
# dtype: float64

# %% [markdown]
# ## Count for all columns

# %%
df0[["Sex"," Length"," Diameter","Height","Whole weight","Shucked weight","Viscera weight",
                          "Shell weight","Rings"]].count()
# The count() method counts the number of not empty values for each row, or column
# Out:
# Sex               4177
#  Length           4177
#  Diameter         4177
# Height            4177
# Whole weight      4177
# Shucked weight    4177
# Viscera weight    4177
# Shell weight      4177
# Rings             4177
# dtype: int64

# %% [markdown]
# ## Value_counts for all categorical columns

# %%
df0[['Sex']].value_counts() #value_counts() function returns object containing counts of unique values
# Out:
# Sex
# M      1528
# I      1342
# F      1307
# dtype: int64

# %% [markdown]
# ## Subset your DataFrame based on one condition

# %%
df0[df0.Rings<7]
# Out:
#      Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 42     I    0.240      0.175   0.045        0.0700          0.0315
# 43     I    0.205      0.150   0.055        0.0420          0.0255
# 44     I    0.210      0.150   0.050        0.0420          0.0175
# 48     I    0.325      0.245   0.070        0.1610          0.0755
# 58     I    0.245      0.190   0.060        0.0860          0.0420
# ...   ..      ...        ...     ...           ...             ...
# 4119   I    0.300      0.215   0.050        0.1185          0.0480
# 4149   I    0.280      0.215   0.070        0.1240          0.0630
# 4151   I    0.350      0.250   0.075        0.1695          0.0835
# 4154   I    0.435      0.330   0.095        0.3930          0.2190
# 4155   I    0.440      0.350   0.110        0.3805          0.1575
#
#       Viscera weight  Shell weight  Rings
# 42            0.0235        0.0200      5
# 43            0.0150        0.0120      5
# 44            0.0125        0.0150      4
# 48            0.0255        0.0450      6
# 58            0.0140        0.0250      4
# ...              ...           ...    ...
# 4119          0.0225        0.0420      4
# 4149          0.0215        0.0300      6
# 4151          0.0355        0.0410      6
# 4154          0.0750        0.0885      6
# 4155          0.0895        0.1150      6
#
# [448 rows x 9 columns]

# %% [markdown]
# ## Subset your DataFrame based on two different conditions

# %%
df0[(df0.Sex == 'F') & (df0.Rings<7)]
# Out:
#      Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 514    F    0.275      0.195   0.070        0.0800          0.0310
# 519    F    0.345      0.250   0.090        0.2030          0.0780
# 521    F    0.360      0.270   0.090        0.1885          0.0845
# 860    F    0.595      0.475   0.160        1.1405          0.5470
# 931    F    0.445      0.335   0.110        0.4355          0.2025
# 944    F    0.465      0.350   0.125        0.4820          0.2300
# 948    F    0.475      0.360   0.120        0.5915          0.3245
# 1039   F    0.660      0.475   0.180        1.3695          0.6410
# 1105   F    0.510      0.400   0.125        0.5450          0.2610
# 1584   F    0.515      0.375   0.110        0.6065          0.3005
# 2123   F    0.290      0.210   0.075        0.2750          0.1130
# 2167   F    0.370      0.275   0.085        0.2405          0.1040
# 2206   F    0.290      0.225   0.075        0.1400          0.0515
# 2567   F    0.460      0.350   0.115        0.4600          0.2025
# 2581   F    0.530      0.420   0.170        0.8280          0.4100
# 3159   F    0.340      0.255   0.085        0.2040          0.0970
# 3161   F    0.335      0.220   0.070        0.1700          0.0760
# 3186   F    0.470      0.360   0.110        0.4965          0.2370
# 3201   F    0.385      0.300   0.100        0.2725          0.1115
# 3983   F    0.585      0.450   0.125        0.8740          0.3545
#
#       Viscera weight  Shell weight  Rings
# 514           0.0215        0.0250      5
# 519           0.0590        0.0550      6
# 521           0.0385        0.0550      5
# 860           0.2310        0.2710      6
# 931           0.1095        0.1195      6
# 944           0.1060        0.1095      6
# 948           0.1100        0.1270      6
# 1039          0.2940        0.3350      6
# 1105          0.1150        0.1385      6
# 1584          0.1310        0.1500      6
# 2123          0.0675        0.0350      6
# 2167          0.0535        0.0700      5
# 2206          0.0235        0.0400      5
# 2567          0.1115        0.1165      6
# 2581          0.2080        0.1505      6
# 3159          0.0210        0.0500      6
# 3161          0.0365        0.0500      6
# 3186          0.1270        0.1300      6
# 3201          0.0570        0.0800      6
# 3983          0.2075        0.2250      6

# %% [markdown]
# ## Subset your DataFrame based on three different conditions

# %%
df0[(df0.Sex == 'F') & (df0.Rings<7) & (df0.Height<0.090)]
# Out:
#      Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 514    F    0.275      0.195   0.070        0.0800          0.0310
# 2123   F    0.290      0.210   0.075        0.2750          0.1130
# 2167   F    0.370      0.275   0.085        0.2405          0.1040
# 2206   F    0.290      0.225   0.075        0.1400          0.0515
# 3159   F    0.340      0.255   0.085        0.2040          0.0970
# 3161   F    0.335      0.220   0.070        0.1700          0.0760
#
#       Viscera weight  Shell weight  Rings
# 514           0.0215         0.025      5
# 2123          0.0675         0.035      6
# 2167          0.0535         0.070      5
# 2206          0.0235         0.040      5
# 3159          0.0210         0.050      6
# 3161          0.0365         0.050      6

# %% [markdown]
# ## Use loc to slice your DataFrame for the 2 columns that returned the largest sum

# %%
df0.loc[:,["Height","Rings"]]
# Out:
#       Height  Rings
# 0      0.095     15
# 1      0.090      7
# 2      0.135      9
# 3      0.125     10
# 4      0.080      7
# ...      ...    ...
# 4172   0.165     11
# 4173   0.135     10
# 4174   0.205      9
# 4175   0.150     10
# 4176   0.195     12
#
# [4177 rows x 2 columns]

# %% [markdown]
# ## Use iloc to slice your DataFrame for the 2 columns that returned the largest mean

# %%
df0.iloc[:,[4,-1]]
# Out:
#       Whole weight  Rings
# 0           0.5140     15
# 1           0.2255      7
# 2           0.6770      9
# 3           0.5160     10
# 4           0.2050      7
# ...            ...    ...
# 4172        0.8870     11
# 4173        0.9660     10
# 4174        1.1760      9
# 4175        1.0945     10
# 4176        1.9485     12
#
# [4177 rows x 2 columns]

# %% [markdown]
# ## Return the first n rows

# %%
df0.head(3)
# Out:
#   Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 0   M    0.455      0.365   0.095        0.5140          0.2245
# 1   M    0.350      0.265   0.090        0.2255          0.0995
# 2   F    0.530      0.420   0.135        0.6770          0.2565
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010          0.15     15
# 1          0.0485          0.07      7
# 2          0.1415          0.21      9

# %% [markdown]
# ## Randomly select n rows

# %%
df0.sample()
# Out:
#      Sex   Length   Diameter  Height  Whole weight  Shucked weight  \
# 3044   I    0.575      0.445    0.16        0.9175            0.45
#
#       Viscera weight  Shell weight  Rings
# 3044          0.1935          0.24      9
